# %% [markdown]
# # CARBON EMISSIONS ACROSS GLOBE (EDA)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# loading the data set
df_ce=pd.read_csv('carbon_emission.csv',skiprows=0)
df_ce
# Out:
#                            Country  Fossil CO2 emissions(Mt CO2)  Unnamed: 2  \
# 0                              NaN                      1990.000    2005.000
# 1                            World                     22674.116   30049.809
# 2    World  International Aviation                       258.941     422.777
# 3    World  International Shipping                       371.804     572.169
# 4                      Afghanistan                         2.546       1.063
# ..                             ...                           ...         ...
# 208                        Vietnam                        20.182      99.231
# 209                 Western Sahara                         0.144       0.227
# 210                          Yemen                         6.887      21.768
# 211                         Zambia                         2.955       2.457
# 212                       Zimbabwe                        17.178      11.388
#
# ...

# %%
# Since the column headers dont convey proper meaning to my data labels. so, i do re-raname the columns of my data frame to convey meaninful
# data set.
df_ce.head(5)
# Out:
#                          Country  Fossil CO2 emissions(Mt CO2)  Unnamed: 2  \
# 0                            NaN                      1990.000    2005.000
# 1                          World                     22674.116   30049.809
# 2  World  International Aviation                       258.941     422.777
# 3  World  International Shipping                       371.804     572.169
# 4                    Afghanistan                         2.546       1.063
#
#    Unnamed: 3 Fossil CO2 emissions                Unnamed: 5  \
# 0    2017.000     2017(% of world)  2017 vs 1990: change (%)
# 1   37077.404              100.00%                    63.50%
# 2     543.381                1.47%                   109.80%
# 3     677.248                1.83%                    82.20%
# 4      11.422                0.03%                   348.60%
#
#     2017  Fossil CO2 emissions                Unnamed: 7  \
# 0  Per land area(t CO2/km2/yr)  Per capita(t CO2/cap/yr)
# ...

# %%
df_ce.columns = ['Country','CO2_emission_1990_MT','CO2_emission_2005_MT','CO2_emission_2017_MT','2017_per_CO2','1990_2017_per_change','CO2_PER_KM_YEAR_T_2017','CO2_PER_CAP_YEAR_T_2017',
              '2018_CO2_INCL_LUCF','2018_CO2_EXCL_LUCF']

# %%
df_ce.columns
# Out:
# Index(['Country', 'CO2_emission_1990_MT', 'CO2_emission_2005_MT',
#        'CO2_emission_2017_MT', '2017_per_CO2', '1990_2017_per_change',
#        'CO2_PER_KM_YEAR_T_2017', 'CO2_PER_CAP_YEAR_T_2017',
#        '2018_CO2_INCL_LUCF', '2018_CO2_EXCL_LUCF'],
#       dtype='object')

# %%
# df_ce.reindex(columns=['Country','CO2_emission_1990_MT','CO2_emission_2005_MT','CO2_emission_2017_MT','2017_per_CO2','1990_2017_per_change','CO2_PER_KM_YEAR_T_2017','CO2_PER_CAP_YEAR_T_2017',
#               '2018_CO2_INCL_LUCF','2018_CO2_EXCL_LUCF'])

# this is one of the method for changing the column labels according to the user.

# %%
# Loading the data set to check
df_ce.head(5)
# Out:
#                          Country  CO2_emission_1990_MT  CO2_emission_2005_MT  \
# 0                            NaN              1990.000              2005.000
# 1                          World             22674.116             30049.809
# 2  World  International Aviation               258.941               422.777
# 3  World  International Shipping               371.804               572.169
# 4                    Afghanistan                 2.546                 1.063
#
#    CO2_emission_2017_MT      2017_per_CO2      1990_2017_per_change  \
# 0              2017.000  2017(% of world)  2017 vs 1990: change (%)
# 1             37077.404           100.00%                    63.50%
# 2               543.381             1.47%                   109.80%
# 3               677.248             1.83%                    82.20%
# 4                11.422             0.03%                   348.60%
#
#         CO2_PER_KM_YEAR_T_2017   CO2_PER_CAP_YEAR_T_2017  \
# ...

# %%
#  remove the first row which is not the actual values of the data set
df_ce.drop(index=0, inplace = True)

# %%
# check for any null values in data sets, which coud actually affect my statistical analysis of my data frame

# %%
df_ce.isnull().sum()
# Out:
# Country                     0
# CO2_emission_1990_MT        0
# CO2_emission_2005_MT        0
# CO2_emission_2017_MT        0
# 2017_per_CO2                0
# 1990_2017_per_change        0
# CO2_PER_KM_YEAR_T_2017      2
# CO2_PER_CAP_YEAR_T_2017     2
# 2018_CO2_INCL_LUCF         27
# 2018_CO2_EXCL_LUCF         28
# dtype: int64

# %%
df_ce.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 1 to 212
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  212 non-null    object
#  1   CO2_emission_1990_MT     212 non-null    float64
#  2   CO2_emission_2005_MT     212 non-null    float64
#  3   CO2_emission_2017_MT     212 non-null    float64
#  4   2017_per_CO2             212 non-null    object
#  5   1990_2017_per_change     212 non-null    object
#  6   CO2_PER_KM_YEAR_T_2017   210 non-null    object
#  7   CO2_PER_CAP_YEAR_T_2017  210 non-null    object
#  8   2018_CO2_INCL_LUCF       185 non-null    object
#  9   2018_CO2_EXCL_LUCF       184 non-null    object
# dtypes: float64(3), object(7)
# memory usage: 16.7+ KB

# %%
df_ce['2018_CO2_INCL_LUCF']=df_ce['2018_CO2_INCL_LUCF'].replace('45.45/2.55','48')

# %%
df_ce['2018_CO2_EXCL_LUCF'] = df_ce['2018_CO2_EXCL_LUCF'].replace('45.54/2.52','48.06')

# %%
# Example of dealing with numerical object type to float point
conversion_cols = df_ce.loc[:,'CO2_PER_CAP_YEAR_T_2017':'2018_CO2_EXCL_LUCF']
conversion_cols.columns

for i in conversion_cols.columns:
    conversion_cols[i]=conversion_cols[i].astype(float)

# %%
conversion_cols.dtypes
# Out:
# CO2_PER_CAP_YEAR_T_2017    float64
# 2018_CO2_INCL_LUCF         float64
# 2018_CO2_EXCL_LUCF         float64
# dtype: object

# %%
# This is how you convert the data type from object type to the float
df_ce['CO2_PER_KM_YEAR_T_2017']=df_ce['CO2_PER_KM_YEAR_T_2017'].astype(float)

# %%
df_ce['CO2_PER_KM_YEAR_T_2017']=df_ce['CO2_PER_KM_YEAR_T_2017'].astype(float)
df_ce['CO2_PER_CAP_YEAR_T_2017']=df_ce['CO2_PER_CAP_YEAR_T_2017'].astype(float)
df_ce['2018_CO2_INCL_LUCF']=df_ce['2018_CO2_INCL_LUCF'].astype(float)
df_ce['2018_CO2_EXCL_LUCF']=df_ce['2018_CO2_EXCL_LUCF'].astype(float)
df_ce['2017_per_CO2'] = df_ce['2017_per_CO2'].str.rstrip('%').astype('float') / 100.0
df_ce['1990_2017_per_change']=df_ce['1990_2017_per_change'].str.rstrip('%').astype(float)

# %%
df_ce.dtypes
# Out:
# Country                     object
# CO2_emission_1990_MT       float64
# CO2_emission_2005_MT       float64
# CO2_emission_2017_MT       float64
# 2017_per_CO2               float64
# 1990_2017_per_change       float64
# CO2_PER_KM_YEAR_T_2017     float64
# CO2_PER_CAP_YEAR_T_2017    float64
# 2018_CO2_INCL_LUCF         float64
# 2018_CO2_EXCL_LUCF         float64
# dtype: object

# %%
df_ce['CO2_PER_KM_YEAR_T_2017'].isnull()
df_ce.head(5)
# Out:
#                          Country  CO2_emission_1990_MT  CO2_emission_2005_MT  \
# 1                          World             22674.116             30049.809
# 2  World  International Aviation               258.941               422.777
# 3  World  International Shipping               371.804               572.169
# 4                    Afghanistan                 2.546                 1.063
# 5                        Albania                 6.583                 4.196
#
#    CO2_emission_2017_MT  2017_per_CO2  1990_2017_per_change  \
# 1             37077.404        1.0000                  63.5
# 2               543.381        0.0147                 109.8
# 3               677.248        0.0183                  82.2
# 4                11.422        0.0003                 348.6
# 5                 5.026        0.0001                 -23.7
#
#    CO2_PER_KM_YEAR_T_2017  CO2_PER_CAP_YEAR_T_2017  2018_CO2_INCL_LUCF  \
# ...

# %%
df_ce.drop(index=[2,3], inplace=True)

# %%
df_ce.index = np.arange(len(df_ce['Country']))

# %%
df_ce.head(10)
# Out:
#                Country  CO2_emission_1990_MT  CO2_emission_2005_MT  \
# 0                World             22674.116             30049.809
# 1          Afghanistan                 2.546                 1.063
# 2              Albania                 6.583                 4.196
# 3              Algeria                65.677                98.197
# 4               Angola                 5.851                15.975
# 5             Anguilla                 0.006                 0.014
# 6  Antigua and Barbuda                 0.223                 0.283
# 7            Argentina               112.434               165.429
# 8              Armenia                20.699                 4.542
# 9                Aruba                 0.297                 0.470
#
#    CO2_emission_2017_MT  2017_per_CO2  1990_2017_per_change  \
# 0             37077.404        1.0000                  63.5
# 1                11.422        0.0003                 348.6
# ...

# %%
df_cem =df_ce

# %%
# df_cem.drop(inplace=True, index=0)

# %%
# Check on outliers for each column if there exist any to actually remove from the data set.
df_cem
# Out:
#             Country  CO2_emission_1990_MT  CO2_emission_2005_MT  \
# 0             World             22674.116             30049.809
# 1       Afghanistan                 2.546                 1.063
# 2           Albania                 6.583                 4.196
# 3           Algeria                65.677                98.197
# 4            Angola                 5.851                15.975
# ..              ...                   ...                   ...
# 205         Vietnam                20.182                99.231
# 206  Western Sahara                 0.144                 0.227
# 207           Yemen                 6.887                21.768
# 208          Zambia                 2.955                 2.457
# 209        Zimbabwe                17.178                11.388
#
#      CO2_emission_2017_MT  2017_per_CO2  1990_2017_per_change  \
# 0               37077.404        1.0000                  63.5
# 1                  11.422        0.0003                 348.6
# ...

# %%
def outlier(data,column):
    Q3 = data[column].quantile(0.75)
    Q1 = data[column].quantile(0.25)
    IQR = Q3-Q1
    data = data[~((data[column]<(Q1-1.5*IQR))|(data[column]>(Q3+1.5*IQR)))]
    return data

# %%
# outlier(df_cem,'2018_CO2_INCL_LUCF')

# %%
df_cem.isnull().sum()
# Out:
# Country                     0
# CO2_emission_1990_MT        0
# CO2_emission_2005_MT        0
# CO2_emission_2017_MT        0
# 2017_per_CO2                0
# 1990_2017_per_change        0
# CO2_PER_KM_YEAR_T_2017      0
# CO2_PER_CAP_YEAR_T_2017     0
# 2018_CO2_INCL_LUCF         25
# 2018_CO2_EXCL_LUCF         26
# dtype: int64

# %%
df_cem=df_cem.dropna()

# %%
# lets now change the world dat by summing the existig values

# %%
# for column in df_cem.columns[df_cem.columns!='Country']:
#     df_cem[column][0]= df_cem[column].sum()

# %%
# df_cem.columns[df_cem.columns != 'Country']

# %% [markdown]
# # EDA

# %%
df_cem
# Out:
#          Country  CO2_emission_1990_MT  CO2_emission_2005_MT  \
# 0          World             22674.116             30049.809
# 1    Afghanistan                 2.546                 1.063
# 2        Albania                 6.583                 4.196
# 3        Algeria                65.677                98.197
# 4         Angola                 5.851                15.975
# ..           ...                   ...                   ...
# 204    Venezuela               109.268               152.464
# 205      Vietnam                20.182                99.231
# 207        Yemen                 6.887                21.768
# 208       Zambia                 2.955                 2.457
# 209     Zimbabwe                17.178                11.388
#
#      CO2_emission_2017_MT  2017_per_CO2  1990_2017_per_change  \
# 0               37077.404        1.0000                  63.5
# 1                  11.422        0.0003                 348.6
# ...

# %%
# The top countries which are contributing to the overal emissions of the global green house gases.
df_cem1=df_cem.sort_values(by='CO2_emission_1990_MT',ascending=False)

# %%
df_cem1.index=np.arange(len(df_cem['Country']))

# %%
df_cem1.head(11)
# Out:
#            Country  CO2_emission_1990_MT  CO2_emission_2005_MT  \
# 0            World             22674.116             30049.809
# 1    United States              5085.897              5971.571
# 2   European Union              4409.339              4249.995
# 3            China              2397.048              6263.064
# 4           Russia              2378.921              1733.950
# 5            Japan              1149.400              1276.863
# 6          Germany              1018.097               837.284
# 7          Ukraine               783.210               354.429
# 8            India               605.968              1210.754
# 9   United Kingdom               589.038               561.543
# 10          Canada               455.827               581.267
#
#     CO2_emission_2017_MT  2017_per_CO2  1990_2017_per_change  \
# 0              37077.404        1.0000                  63.5
# 1               5107.393        0.1377                   0.4
# ...

# %%
# Visualization PLOTS

# %%
# BAR Plot to check the contribution of first 10 countries in the global GHG emissions

# %%
# Top 10 countries in 1990 carbon Emission 
fig = plt.figure(figsize=(25,12))
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
bar=sns.barplot(x=df_cem1.loc[1:11,'Country'], y=df_cem1.loc[1:11,'CO2_emission_1990_MT'],palette=sns.color_palette("flare", 10))
bar.set_xticklabels(bar.get_xticklabels(),rotation=60)
plt.xlabel('Top 10 Countries',fontsize=20,)
plt.ylabel('C02 Emissions in Metric Tonnes Y=1990',fontsize=20)
plt.annotate('8th position',xy=(7,800),xytext=(7.6,1500),arrowprops =dict(facecolor='Red', shrink=0.05),size=20)
# Out:
# Text(7.6, 1500, '8th position')

# %%
df_cem2=df_cem.sort_values(by='CO2_emission_2005_MT',ascending=False)
df_cem2.index=np.arange(len(df_cem['Country']))
df_cem2.head(11)
# Out:
#            Country  CO2_emission_1990_MT  CO2_emission_2005_MT  \
# 0            World             22674.116             30049.809
# 1            China              2397.048              6263.064
# 2    United States              5085.897              5971.571
# 3   European Union              4409.339              4249.995
# 4           Russia              2378.921              1733.950
# 5            Japan              1149.400              1276.863
# 6            India               605.968              1210.754
# 7          Germany              1018.097               837.284
# 8           Canada               455.827               581.267
# 9   United Kingdom               589.038               561.543
# 10     South Korea               270.056               514.946
#
#     CO2_emission_2017_MT  2017_per_CO2  1990_2017_per_change  \
# 0              37077.404        1.0000                  63.5
# 1              10877.218        0.2934                 353.8
# ...

# %%
# Top 10 countries in 2005 carbon Emission 
fig = plt.figure(figsize=(25,12))
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
bar=sns.barplot(x=df_cem2.loc[1:11,'Country'], y=df_cem2.loc[1:11,'CO2_emission_2005_MT'],palette=sns.color_palette("rocket", 10))
bar.set_xticklabels(bar.get_xticklabels(),rotation=60)
plt.xlabel('Top 10 Countries',fontsize=20,)
plt.ylabel('C02 Emissions in Metric Tonnes Y=1990',fontsize=20)
plt.annotate('6th position',xy=(5.2,1300),xytext=(5.5,2000), arrowprops =dict(facecolor='Red', shrink=0.05),size=20)
# Out:
# Text(5.5, 2000, '6th position')

# %%
df_cem3=df_cem.sort_values(by='CO2_emission_2017_MT',ascending=False)
df_cem3.index=np.arange(len(df_cem['Country']))
df_cem3
# Out:
#             Country  CO2_emission_1990_MT  CO2_emission_2005_MT  \
# 0             World             22674.116             30049.809
# 1             China              2397.048              6263.064
# 2     United States              5085.897              5971.571
# 3    European Union              4409.339              4249.995
# 4             India               605.968              1210.754
# ..              ...                   ...                   ...
# 179           Tonga                 0.064                 0.120
# 180        Dominica                 0.033                 0.035
# 181         Vanuatu                 0.130                 0.063
# 182    Cook Islands                 0.043                 0.058
# 183        Kiribati                 0.020                 0.033
#
#      CO2_emission_2017_MT  2017_per_CO2  1990_2017_per_change  \
# 0               37077.404        1.0000                  63.5
# 1               10877.218        0.2934                 353.8
# ...

# %%
# Top 10 countries in 2017 carbon Emission 
fig = plt.figure(figsize=(25,12))
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
bar=sns.barplot(x=df_cem3.loc[1:11,'Country'], y=df_cem3.loc[1:11,'CO2_emission_2017_MT'],palette=sns.color_palette("crest", 10))
bar.set_xticklabels(bar.get_xticklabels(),rotation=60)
plt.xlabel('Top 10 Countries',fontsize=20,)
plt.ylabel('C02 Emissions in Metric Tonnes Y=1990',fontsize=20)
plt.annotate('4th position',xy=(3,2500),xytext=(3.5,3700),arrowprops =dict(facecolor='Red', shrink=0.05),size=20)
# Out:
# Text(3.5, 3700, '4th position')

# %%
# Pie chart for 10 countries in 1990

# %%
fig=plt.figure(figsize=(10,8))
explode=(0.1,0,0,0,0,0,0,0.2,0,0,0)
plt.pie(x=df_cem1.loc[1:11,'CO2_emission_1990_MT'],explode=explode,pctdistance=0.85,labels=df_cem1.loc[1:11,'Country'],autopct='%1.2f%%',colors=sns.color_palette("flare", 10))
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig.gca().add_artist(centre_circle)

# %%
# Pie chart for 10 countries in 2005

# %%
fig=plt.figure(figsize=(10,8))
explode=(0.1,0,0,0.2,0,0,0,0,0,0,0)
plt.pie(x=df_cem3.loc[1:11,'CO2_emission_2005_MT'],explode=explode,pctdistance=0.85,labels=df_cem3.loc[1:11,'Country'],autopct='%1.2f%%',wedgeprops=dict(width=0.5),colors=sns.color_palette("crest", 10))
# Out:
# ([<matplotlib.patches.Wedge at 0x1e3249c5160>,
# ...
#  [Text(0.8016988908784437, 0.8929047476434837, 'China'),
#   Text(-0.8668654316226516, 0.6771590089910008, 'United States'),
#   Text(-0.8367678460549158, -0.7140165066779738, 'European Union'),
#   Text(-0.17202965026267414, -1.2885673437700111, 'India'),
#   Text(0.2847351043181894, -1.0625092566038707, 'Russia'),
#   Text(0.6789732840719269, -0.8654451337413497, 'Japan'),
#   Text(0.8938015849101454, -0.6411854075165095, 'Germany'),
#   Text(0.9947074874153, -0.46963498004294874, 'South Korea'),
#   Text(1.047762005078052, -0.33495489355257985, 'Iran'),
#   Text(1.0778004421483152, -0.21987770897682302, 'Saudi Arabia'),
#   Text(1.0966656220616926, -0.08558337097848563, 'Canada')],
#  [Text(0.6346782886121012, 0.7068829252177579, '26.71%'),
#   Text(-0.6698505607993216, 0.5232592342203187, '25.47%'),
#   Text(-0.6465933355878893, -0.5517400278875251, '18.13%'),
#   Text(-0.13894702521215985, -1.0407659315065474, '5.16%'),
# ...

# %%
# Pie chart for 10 countries in 2005

# %%
fig=plt.figure(figsize=(10,8))
explode=(0.1,0,0,0.2,0,0,0,0,0,0,0)
plt.pie(x=df_cem2.loc[1:11,'CO2_emission_2005_MT'],explode=explode,pctdistance=0.85,labels=df_cem2.loc[1:11,'Country'],autopct='%1.2f%%',wedgeprops=dict(width=0.5),colors=sns.color_palette("viridis", 10))
# Out:
# ([<matplotlib.patches.Wedge at 0x1e324a41730>,
# ...
#  [Text(0.8096468675443039, 0.8857042112780635, 'China'),
#   Text(-0.8486913697834445, 0.699802085489248, 'United States'),
#   Text(-0.8653187494061669, -0.6791343474793096, 'European Union'),
#   Text(-0.14547558596029375, -1.2918346852014424, 'Russia'),
#   Text(0.31135589960325694, -1.0550154045236717, 'Japan'),
#   Text(0.6362090718505076, -0.8973505540729976, 'India'),
#   Text(0.8535444440345652, -0.6938745434570469, 'Germany'),
#   Text(0.9682086729506141, -0.5220842514606344, 'Canada'),
#   Text(1.035908704049509, -0.3699907524174993, 'United Kingdom'),
#   Text(1.0779978216548263, -0.21890796355420616, 'South Korea'),
#   Text(1.097602041764425, -0.07259309825710453, 'Italy\xa0San Marino Vatican City')],
#  [Text(0.6409704368059073, 0.7011825005951335, '26.43%'),
#   Text(-0.6558069675599344, 0.5407561569689643, '25.20%'),
#   Text(-0.6686553972684016, -0.5247856321431028, '17.93%'),
# ...

# %%
# The european  usnion has the cloud of countries in it have the fair 
# idea of how to standardize  the data cumulative to the European union

# %%
df_cem
# Out:
#          Country  CO2_emission_1990_MT  CO2_emission_2005_MT  \
# 0          World             22674.116             30049.809
# 1    Afghanistan                 2.546                 1.063
# 2        Albania                 6.583                 4.196
# 3        Algeria                65.677                98.197
# 4         Angola                 5.851                15.975
# ..           ...                   ...                   ...
# 204    Venezuela               109.268               152.464
# 205      Vietnam                20.182                99.231
# 207        Yemen                 6.887                21.768
# 208       Zambia                 2.955                 2.457
# 209     Zimbabwe                17.178                11.388
#
#      CO2_emission_2017_MT  2017_per_CO2  1990_2017_per_change  \
# 0               37077.404        1.0000                  63.5
# 1                  11.422        0.0003                 348.6
# ...
